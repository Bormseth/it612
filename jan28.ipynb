# %% [markdown]
# <a href="https://colab.research.google.com/github/Bormseth/it612/blob/main/jan28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
# const addTax = (price, rate) => price + (price * rate);
# console.log("addTax:")
# console.log(addTax(10, 0.1));
# console.log(addTax(35, 0.175));
#
# function createBurner(secret, limit) {
#   return func() {
#
#   }
# }
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# 11
# 41.125
